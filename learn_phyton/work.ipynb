# %%
#424
s = input().split()
print(len(set(s)))
# Out:
# 19

# %%
#425
a, b = map(int, input().split())
print(b, a)
# Out:
# 12 11

# %%
n = input()
a, b = n.split('.')
print(a, b)
# Out:
# 12 567

# %%
#618
words = input()
def change():
    if words.startswith("Is"):
        return words
    else:
        return "Is "+words
print(change())
# Out:
# Is fggjf

# %%
#620
tag, word = input().split()
def html(tag, word):
    return "<"+tag+">"+word+"</"+tag+">"
print(html(tag, word))
# Out:
# <strong>python</strong>

# %%
#624

first, second = input().split()
def put(first, second):
    half = (len(second))//2
    return second[:half] + first + second[half:]
print(put(first,second))
# Out:
# [python]

# %%
#626
numbers = list(map(int, input().split()))
for i in numbers:
    print("*"*i)
# Out:
# **
# *******
# *
# ****
# **
# ***
# *********
# ***

# %%
#655
text

# %%
#657
a = int(input())
n = int(input())
print(a**n)
# Out:
# 0.5

# %%
#659
day = int(input())
month = int(input())
year = int(input())
if day>30 and (month!=1 or month!=3 or month!=5 or month!=7 or month!=8 or month!=10 or month!=12):
    print(False)

# %%
#660
n = int(input())
s = 0
for i in range(1, n//2 + 1):
    if n%i == 0:
        s+=i
if s == n:
    print("True")
else:
    print("False")
# Out:
# True

# %%
#671
n = int(input())
factorial = 1
for i in range(1, n+1):
    factorial*=i
print(factorial)
# Out:
# 120

# %%
#675
numbers = list(map(int, input().split()))
difference = numbers[1] - numbers[0]
for i in range(1, len(numbers)+1):
    if numbers[i] - numbers[i-1] != difference:
        print("False")
