# %%
n = int(input())

# %%
for i in range(20, n+1):
    print(i)
# Out:
# 20
# 21
# 22
# 23
# 24
# 25

# %%
n = int(input())
for i in range(1, n+1):
    print(str(i)*i)
# Out:
# 1
# 22
# 333
# 4444
# 55555
# 666666
# 7777777
# 88888888
# 999999999

# %%
n = int(input())
for i in range(1,n+1):
    print(i,i*0.453)
# Out:
# 1 0.453
# 2 0.906
# 3 1.359
# 4 1.812
# 5 2.265

# %%
n = int(input())
for i in range(1, n+1):
    if i%3 == 0 and i%5 !=0:
        print(f"*{3}*")
    elif i%5 == 0 and i%3 !=0:
        print(f"*{5}*")
    elif i%3 == 0 and i%5 == 0:
        print(f"*{35}*")
    else:
        print(i)
# Out:
# 1
# 2
# *3*
# 4
# *5*
# *3*
# 7
# 8
# *3*
# *5*
# 11
# *3*
# 13
# 14
# *35*
# 16

# %%
lst = [1, 2, 3, 4]
lst2 = []
for i in lst.copy():
    lst2.append(lst[-1])
    lst.pop(-1)
print(lst2)
# Out:
# [4, 3, 2, 1]
